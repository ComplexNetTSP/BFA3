# %%
# %matplotlib inline

import quandl as ql
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import csv

ql.ApiConfig.api_key = "y-zCjPnDPkRm_5tTzGRY"

# %%
with open("sp500.csv", 'r') as sp500:
    reader = csv.reader(sp500)
    sp500_list = next(reader)

# %%
print(sp500_list)
# Out:
# ['ABT', 'ABBV', 'ACN', 'ACE', 'ADBE', 'ADT', 'AAP', 'AES', 'AET', 'AFL', 'AMG', 'A', 'GAS', 'APD', 'ARG', 'AKAM', 'AA', 'AGN', 'ALXN', 'ALLE', 'ADS', 'ALL', 'ALTR', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'AON', 'APA', 'AIV', 'AMAT', 'ADM', 'AIZ', 'T', 'ADSK', 'ADP', 'AN', 'AZO', 'AVGO', 'AVB', 'AVY', 'BHI', 'BLL', 'BAC', 'BK', 'BCR', 'BXLT', 'BAX', 'BBT', 'BDX', 'BBBY', 'BRK_B', 'BBY', 'BLX', 'HRB', 'BA', 'BWA', 'BXP', 'BSK', 'BMY', 'BRCM', 'BF_B', 'CHRW', 'CA', 'CVC', 'COG', 'CAM', 'CPB', 'COF', 'CAH', 'HSIC', 'KMX', 'CCL', 'CAT', 'CBG', 'CBS', 'CELG', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHK', 'CVX', 'CMG', 'CB', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CTXS', 'CLX', 'CME', 'CMS', 'COH', 'KO', 'CCE', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CSC', 'CAG', 'COP', 'CNX', 'ED', 'STZ', 'GLW', 'COST', 'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DLPH', 'DAL', 'XRAY', 'DVN', 'DO', 'DTV', 'DFS', 'DISCA', 'DISCK', '
# ...

# %%
def get_close_price(ticker, sdate, edate):
    data = ql.get("WIKI/"+ticker, 
                      start_date=sdate, 
                      end_date=edate,
                      returns="pandas")['Adj. Close']
    return data

# %%
sdate = "2007-01-01"
edate = "2017-01-01"
data = []
colums_name = []
for ticker in sp500_list:
    try:
        data.append(get_close_price(ticker, sdate, edate))
        colums_name.append(ticker)
    except:
        print("Ticker: ", ticker, "was not found")
# Out:
# Ticker:  BSK was not found
# Ticker:  EA was not found
# Ticker:  FSIV was not found
# Ticker:  KIM.KMI was not found
# Ticker:  MMV was not found
# Ticker:  RLC was not found
# Ticker:  TJK was not found

# %%
df = pd.concat(data, axis=1)
df.columns = colums_name

# %%
def split_dataset(df, nb_split=3):
    lenght = len(df)
# Out:
# 2518

# %%
sdate = "2017-01-01"
edate = "2017-03-01"
data = ql.get("WIKI/"+"AAPL", 
                      start_date=sdate, 
                      end_date=edate,
                      returns="pandas")

# %%
data
# Out:
#                Open      High       Low    Close       Volume  Ex-Dividend  \
# Date
# 2017-01-03  115.800  116.3300  114.7600  116.150   28781865.0         0.00
# 2017-01-04  115.850  116.5100  115.7500  116.020   21118116.0         0.00
# 2017-01-05  115.920  116.8642  115.8100  116.610   22193587.0         0.00
# 2017-01-06  116.780  118.1600  116.4700  117.910   31751900.0         0.00
# 2017-01-09  117.950  119.4300  117.9400  118.990   33561948.0         0.00
# 2017-01-10  118.770  119.3800  118.3000  119.110   24462051.0         0.00
# 2017-01-11  118.740  119.9300  118.6000  119.750   27588593.0         0.00
# 2017-01-12  118.895  119.3000  118.2100  119.250   27086220.0         0.00
# 2017-01-13  119.110  119.6200  118.8100  119.040   26111948.0         0.00
# 2017-01-17  118.340  120.2400  118.2200  120.000   34439843.0         0.00
# 2017-01-18  120.000  120.5000  119.7100  119.990   23712961.0         0.00
# ...

# %%
order = pd.read_csv("order.csv", header=None, 
                    names=["command", "ticker", "vol"], 
                   parse_dates=True)
order.head()
# Out:
#             command  ticker   vol
# date        command  ticker   vol
# 2017-02-17      BUY    AAPL  100
# 2017-02-17      BUY    AAPL  100
# 2017-02-17     SELL    AAPL   50
# 2017-02-17      BUY    GOOG   100

# %%
order.reset_index(inplace=True)
data.reset_index(inplace=True)
pd.merge(data, order, how='inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-228e684ad698> in <module>()
# ----> 1 order.reset_index(inplace=True)
#       2 data.reset_index(inplace=True)
#       3 pd.merge(data, order, how='inner')
#
# /usr/local/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    2956                 # to ndarray and maybe infer different dtype
#    2957                 level_values = _maybe_casted_values(lev, lab)
# -> 2958                 new_obj.insert(0, name, level_values)
#    2959
#    2960         new_obj.index = new_index
#
# /usr/local/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    2421         value = self._sanitize_column(column, value, broadcast=False)
#    2422         self._data.insert(loc, column, value,
# ...

# %%
data.columns.
# Out:
#     index       Date     Open      High       Low    Close       Volume  \
# 0       0 2017-01-03  115.800  116.3300  114.7600  116.150   28781865.0
# 1       1 2017-01-04  115.850  116.5100  115.7500  116.020   21118116.0
# 2       2 2017-01-05  115.920  116.8642  115.8100  116.610   22193587.0
# 3       3 2017-01-06  116.780  118.1600  116.4700  117.910   31751900.0
# 4       4 2017-01-09  117.950  119.4300  117.9400  118.990   33561948.0
# 5       5 2017-01-10  118.770  119.3800  118.3000  119.110   24462051.0
# 6       6 2017-01-11  118.740  119.9300  118.6000  119.750   27588593.0
# 7       7 2017-01-12  118.895  119.3000  118.2100  119.250   27086220.0
# 8       8 2017-01-13  119.110  119.6200  118.8100  119.040   26111948.0
# 9       9 2017-01-17  118.340  120.2400  118.2200  120.000   34439843.0
# 10     10 2017-01-18  120.000  120.5000  119.7100  119.990   23712961.0
# 11     11 2017-01-19  119.400  120.0900  119.3700  119.780   25597291.0
# ...
